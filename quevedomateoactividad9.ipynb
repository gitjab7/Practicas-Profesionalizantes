# %% [markdown]
# "import pandas as pd" para importar la libreria pandas y "aeropuertos = pd.read_csv("ar.airports.csv")" para definir la variable que va a leer el contenido del dataset

# %%
import pandas as pd

# %%
import plotly.express as px

# %%
import folium

# %%
aeropuertos = pd.read_csv("ar-airports.csv")

# %% [markdown]
# pregunta 1) informacion general:

# %%
print(aeropuertos["type"].value_counts())
# Out:
# type
# small_airport     694
# heliport          148
# medium_airport     69
# closed             42
# large_airport       2
# balloonport         1
# Name: count, dtype: int64
